# %%
# Data
company_detail_list = [
    {
        'name': 'Company 1',
        'domain': 'Retail',
        'country': 'United States'
    },
    {
        'name': 'Company 2',
        'domain': 'Technology',
        'country': 'United Kingdom'
    },
    {
        'name': 'Company 3',
        'domain': 'Healthcare',
        'country': 'United States'
    }
]

employee_detail_list = [
    {
        'name': 'EMP-0001',
        'first_name': 'John',
        'last_name': 'Doe',
        'full_name': 'John Doe',
        'company': 'Company 1',
        'nationality': 'Australia'
    },
    {
        'name': 'EMP-0002',
        'first_name': 'Tom',
        'last_name': 'Smith',
        'full_name': 'Tom Smith',
        'company': 'Company 2',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0003',
        'first_name': 'Andrew',
        'last_name': 'Sebastian',
        'full_name': 'Andrew Sebastian',
        'company': 'Company 3',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0005',
        'first_name': 'Ying Han',
        'last_name': 'Tan',
        'full_name': 'Ying Han Tan',
        'company': 'Company 1',
        'nationality': 'Australia'
    },
    {
        'name': 'EMP-0015',
        'first_name': 'Kenneth',
        'last_name': 'Ng',
        'full_name': 'Kenneth Ng',
        'company': 'Company 3',
        'nationality': 'United States'
    },
    {
        'name': 'EMP-0018',
        'first_name': 'Rubby',
        'last_name': 'Lee',
        'full_name': 'Rubby Lee',
        'company': 'Company 2',
        'nationality': 'Hong Kong'
    },
    {
        'name': 'EMP-0017',
        'first_name': 'Robert',
        'last_name': 'White',
        'full_name': 'Robert White',
        'company': 'Company 1',
        'nationality': 'United Kingdom'
    }
]

# %%
# Task 1
sorted_companies = sorted(company_detail_list, key=lambda x: x['name'], reverse=True)
result_task_1 = [{'name': company['name']} for company in sorted_companies]

print("[")
for company in result_task_1:
    print(f'    {company},')
print("]")
# Out:
# [
#     {'name': 'Company 3'},
#     {'name': 'Company 2'},
#     {'name': 'Company 1'},
# ]

# %%
#Task 2
for company in company_detail_list:
    print(f"{company['name']}: {company['domain']} ({company['country']})")
# Out:
# Company 1: Retail (United States)
# Company 2: Technology (United Kingdom)
# Company 3: Healthcare (United States)

# %%
# Task 3
employees_by_domain = {}
for employee in employee_detail_list:
    company_name = employee['company']
    company_domain = next((company['domain'] for company in company_detail_list if company['name'] == company_name), None)
    if company_domain not in employees_by_domain:
        employees_by_domain[company_domain] = []
    employees_by_domain[company_domain].append(employee['full_name'])

print("{")
for domain, employees in employees_by_domain.items():
    print(f'    "{domain}": [')
    for employee in employees:
        print(f'        "{employee}",')
    print("    ],")
print("}")
# Out:
# {
#     "Retail": [
#         "John Doe",
#         "Ying Han Tan",
#         "Robert White",
#     ],
#     "Technology": [
#         "Tom Smith",
#         "Rubby Lee",
#     ],
#     "Healthcare": [
#         "Andrew Sebastian",
#         "Kenneth Ng",
#     ],
# }

# %%
#Task 4
def employees_with_country(employee_list, company_list):
    result = []
    for employee in employee_list:
        company_info = next((company for company in company_list if company['name'] == employee['company']), None)
        if company_info:
            result.append({
                'full_name': employee['full_name'],
                'company': employee['company'],
                'country': company_info['country']
            })
    return result

hasil = employees_with_country(employee_detail_list, company_detail_list)

formatted_result = []
for employee_info in hasil:
    formatted_result.append({
        "full_name": employee_info['full_name'],
        "company": employee_info['company'],
        "country": employee_info['country']
    })

import json
print(json.dumps(formatted_result, indent=4))
# Out:
# [
#     {
#         "full_name": "John Doe",
#         "company": "Company 1",
#         "country": "United States"
#     },
#     {
#         "full_name": "Tom Smith",
#         "company": "Company 2",
#         "country": "United Kingdom"
#     },
#     {
#         "full_name": "Andrew Sebastian",
#         "company": "Company 3",
#         "country": "United States"
#     },
#     {
#         "full_name": "Ying Han Tan",
#         "company": "Company 1",
#         "country": "United States"
#     },
#     {
#         "full_name": "Kenneth Ng",
#         "company": "Company 3",
#         "country": "United States"
#     },
#     {
#         "full_name": "Rubby Lee",
#         "company": "Company 2",
#         "country": "United Kingdom"
#     },
#     {
#         "full_name": "Robert White",
#         "company": "Company 1",
#         "country": "United States"
#     }
# ]

# %%
#Task 5
def companies_employee_nationality(employee_list, company_list):
    result = []
    for company in company_list:
        company_name = company['name']
        nationality_count = {}
        for employee in employee_list:
            if employee['company'] == company_name:
                nationality = employee['nationality']
                if nationality in nationality_count:
                    nationality_count[nationality] += 1
                else:
                    nationality_count[nationality] = 1
        result.append({
            'company': company_name,
            'employee_nationality': nationality_count
        })
    return result

result = companies_employee_nationality(employee_detail_list, company_detail_list)

import json
print(json.dumps(result, indent=4))
# Out:
# [
#     {
#         "company": "Company 1",
#         "employee_nationality": {
#             "Australia": 2,
#             "United Kingdom": 1
#         }
#     },
#     {
#         "company": "Company 2",
#         "employee_nationality": {
#             "United States": 1,
#             "Hong Kong": 1
#         }
#     },
#     {
#         "company": "Company 3",
#         "employee_nationality": {
#             "United States": 2
#         }
#     }
# ]
